# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/samru/Downloads/weatherHistory.csv")

# %%
df
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df['Wind Speed (km/h)'].unique
# Out:
# <bound method Series.unique of 0        14.1197
# 1        14.2646
# 2         3.9284
# 3        14.1036
# 4        11.0446
#           ...
# 96448    10.9963
# 96449    10.0947
# 96450     8.9838
# 96451    10.5294
# 96452     5.8765
# Name: Wind Speed (km/h), Length: 96453, dtype: float64>

# %%
df[df['Summary'] =='Clear'].Summary.value_counts()
# Out:
# Clear    10890
# Name: Summary, dtype: int64

# %%
df[df['Wind Speed (km/h)'] == 4]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Summary, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df.groupby('Summary').get_group('Clear')
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 223    2006-04-18 07:00:00.000 +0200   Clear        rain         8.688889
# 309    2006-04-20 21:00:00.000 +0200   Clear        rain        12.266667
# 337    2006-04-22 01:00:00.000 +0200   Clear        rain         9.355556
# 338    2006-04-22 02:00:00.000 +0200   Clear        rain         9.861111
# 357    2006-04-22 21:00:00.000 +0200   Clear        rain        12.494444
# ...                              ...     ...         ...              ...
# 96432  2016-09-09 03:00:00.000 +0200   Clear        rain        15.594444
# 96433  2016-09-09 04:00:00.000 +0200   Clear        rain        15.011111
# 96434  2016-09-09 05:00:00.000 +0200   Clear        rain        15.016667
# 96435  2016-09-09 06:00:00.000 +0200   Clear        rain        13.872222
# 96436  2016-09-09 07:00:00.000 +0200   Clear        rain        16.072222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# ...

# %%
df[df.isna()]
# Out:
#       Formatted Date Summary Precip Type  Temperature (C)  \
# 0                NaN     NaN         NaN              NaN
# 1                NaN     NaN         NaN              NaN
# 2                NaN     NaN         NaN              NaN
# 3                NaN     NaN         NaN              NaN
# 4                NaN     NaN         NaN              NaN
# ...              ...     ...         ...              ...
# 96448            NaN     NaN         NaN              NaN
# 96449            NaN     NaN         NaN              NaN
# 96450            NaN     NaN         NaN              NaN
# 96451            NaN     NaN         NaN              NaN
# 96452            NaN     NaN         NaN              NaN
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                           NaN       NaN                NaN
# 1                           NaN       NaN                NaN
# 2                           NaN       NaN                NaN
# ...

# %%
df.isnull().sum()
# Out:
# Formatted Date                0
# Weather condition             0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Loud Cover                    0
# Pressure (millibars)          0
# Daily Summary                 0
# dtype: int64

# %%
df.rename(columns={'Summary':'Weather condition'},inplace=True)

# %%
df
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200     Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200     Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200     Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200     Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200     Mostly Cloudy        rain
# ...                              ...               ...         ...
# 96448  2016-09-09 19:00:00.000 +0200     Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200     Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200     Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200     Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200     Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
df['Visibility (km)'].mean()
# Out:
# 10.347324929237148

# %%
df['Pressure (millibars)'].std()
# Out:
# 116.96990568258147

# %%
df['Humidity'].var()
# Out:
# 0.03820959171844407

# %%
df[df['Precip Type'] == 'snow']
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 1562   2006-12-13 02:00:00.000 +0100             Foggy        snow
# 1563   2006-12-13 03:00:00.000 +0100             Foggy        snow
# 1564   2006-12-13 04:00:00.000 +0100             Foggy        snow
# 1565   2006-12-13 05:00:00.000 +0100             Foggy        snow
# 1566   2006-12-13 06:00:00.000 +0100             Foggy        snow
# ...                              ...               ...         ...
# 93265  2016-03-28 05:00:00.000 +0200             Foggy        snow
# 93266  2016-03-28 06:00:00.000 +0200             Foggy        snow
# 93267  2016-03-28 07:00:00.000 +0200             Foggy        snow
# 93311  2016-03-03 03:00:00.000 +0100     Partly Cloudy        snow
# 93506  2016-03-09 06:00:00.000 +0100             Foggy        snow
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 1562         -0.483333                 -4.150000      1.00            11.0929
# ...

# %%
df[(df['Wind Speed (km/h)'] > 24) & (df['Visibility (km)'] == 25)]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather condition, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df.groupby('Weather condition').mean()
# Out:
#                                      Temperature (C)  \
# Weather condition
# Breezy                                      7.922016
# Breezy and Dry                             21.111111
# Breezy and Foggy                           -0.510317
# Breezy and Mostly Cloudy                   11.093411
# Breezy and Overcast                         7.241614
# Breezy and Partly Cloudy                   12.492761
# Clear                                      11.925109
# Dangerously Windy and Partly Cloudy         8.944444
# Drizzle                                    10.847578
# Dry                                        29.083660
# Dry and Mostly Cloudy                      26.838492
# Dry and Partly Cloudy                      26.605749
# Foggy                                       1.464035
# Humid and Mostly Cloudy                    20.886389
# Humid and Overcast                         21.515079
# Humid and Partly Cloudy                    21.568301
# ...

# %%
df.groupby('Weather condition').describe()
# Out:
#                                     Temperature (C)                        \
#                                               count       mean        std
# Weather condition
# Breezy                                         54.0   7.922016  10.706180
# Breezy and Dry                                  1.0  21.111111        NaN
# Breezy and Foggy                               35.0  -0.510317   5.081695
# Breezy and Mostly Cloudy                      516.0  11.093411   6.683639
# Breezy and Overcast                           528.0   7.241614   5.592556
# Breezy and Partly Cloudy                      386.0  12.492761   8.140788
# Clear                                       10890.0  11.925109  10.018959
# Dangerously Windy and Partly Cloudy             1.0   8.944444        NaN
# Drizzle                                        39.0  10.847578   2.485500
# Dry                                            34.0  29.083660   6.797474
# ...

# %%
df[(df['Visibility (km)'] > 40) | (df['Weather condition'] == 'Clear')]
# Out:
#                       Formatted Date Weather condition Precip Type  \
# 223    2006-04-18 07:00:00.000 +0200             Clear        rain
# 309    2006-04-20 21:00:00.000 +0200             Clear        rain
# 337    2006-04-22 01:00:00.000 +0200             Clear        rain
# 338    2006-04-22 02:00:00.000 +0200             Clear        rain
# 357    2006-04-22 21:00:00.000 +0200             Clear        rain
# ...                              ...               ...         ...
# 96432  2016-09-09 03:00:00.000 +0200             Clear        rain
# 96433  2016-09-09 04:00:00.000 +0200             Clear        rain
# 96434  2016-09-09 05:00:00.000 +0200             Clear        rain
# 96435  2016-09-09 06:00:00.000 +0200             Clear        rain
# 96436  2016-09-09 07:00:00.000 +0200             Clear        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 223           8.688889                  8.688889      0.93             1.4329
# ...

# %%
df[(df['Visibility (km)'] > 40)]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather condition, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []

# %%
df[(df['Humidity'] > 50) & (df['Weather condition'] == 'Clear')]
# Out:
# Empty DataFrame
# Columns: [Formatted Date, Weather condition, Precip Type, Temperature (C), Apparent Temperature (C), Humidity, Wind Speed (km/h), Wind Bearing (degrees), Visibility (km), Loud Cover, Pressure (millibars), Daily Summary]
# Index: []
